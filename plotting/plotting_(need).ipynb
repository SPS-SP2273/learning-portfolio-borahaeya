# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 A simple plot

# %%
from matplotlib import pyplot as plt
#need to import when opened as new

# %% [markdown]
# ## 1.1 Let’s look at some code.

# %%
x= [0,1,2,3,4,5,6]
y_1= [0,2,4,6,8,10,12]
y_2= [0,3,6,9,12,15,18]
#DATA FOR PLOTTING

plt.plot(x,y_1,label= 'Y values', color='red', linestyle='dashed', linewidth=2)
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
#grid lines
#alpha- transparency of grid lines, the higher value the higher colour intensity and opaque
plt.legend(loc='upper left') #legend location upper left
#order of keyword arguments e.g. color, linewidth doesnt matter

# %% [markdown]
# ### Things to note

# %% [markdown]
# plt.plot(x,y,color='red',linestyle='dashed',linewidth=2)
#
# plt.plot(x,y,c='red',ls='dashed',lw=2)
#
# ABBREVIATIONS
#
# color -> c
#
# linestyle -> ls
#
# 'dashed' or '--'
# default straight line or '-'
#
# linewidth -> lw

# %%
plt.plot(x,y_1,y_2)
#two separate lines, default styling no specifics stated

# %% [markdown]
# ## 1.2 Adding another plot

# %%
plt.plot(x,y_2,label='Y2 values',color='blue')

# %%
plt.plot(x,y_1,label= 'Y1 values', color='red', linestyle='dashed')
plt.plot(x,y_2,label='Y2 values',color='blue')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25) 
plt.legend(loc='upper left') 

#two diff y value sets in same cell produces plots together in one plot

# %% [markdown]
# ## 1.3 Yet another plot but with error bars

# %%
x= [0,1,2,3,4,5,6]
y_1= [0,2,4,6,8,10,12] # from 0, multiples of 2
y_2= [0,3,6,9,12,15,18] # from 0, multiples of 3
y_3= [0,4,8,12,16,20,24] # from 0, multiples of 4
x_error,y_error=.1,0.75 #error bar sizes

plt.plot(x,y_1,label= 'Y1 values', color='red', linestyle='dashed')
plt.plot(x,y_2,label='Y2 values',color='blue')

#
plt.errorbar(x,y_3,xerr=x_error,yerr=y_error,label='Y3 with errors',color='green')
# xerr x error bar, y error bar

plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25) 
plt.legend(loc='upper left')

# %% [markdown]
# # 2 Better with NumPy

# %%
import numpy as np
#numpy arrays better than python lists

x= [0,1,2,3,4,5,6]
y_1= [0,2,4,6,8,10,12] 
y_2= [0,3,6,9,12,15,18]

np_x=np.array(x)
np_y_1=np.array(y_1)
np_y_2=np.array(y_2)

plt.plot(np_x,np_y_1,label= 'Y1 values', color='red', linestyle='dashed')
plt.plot(np_x,np_y_2,label='Y2 values',color='blue')

# %% [markdown]
# ## 2.1 Adding mathematical functions

# %%
x=np.array([0,1,2,3,4,5,6])
x2=x**2 
sin_x=np.sin(x)

plt.plot(x,x2,label='x^2',color='red',linestyle='dashed')
plt.plot(x,sin_x,label='sin(x)',color='blue')
plt.legend()

# %% [markdown]
# ## We need another axis!

# %%
#twinx() have another y axis that shares the same x axis

x=np.array([0,1,2,3,4,5,6])
x2=x**2 
sin_x=np.sin(x)

plt.plot(x,x2,label='x^2',color='red',linestyle='dashed')
plt.legend(loc='lower left')

plt.twinx()

plt.plot(x,sin_x,label='sin(x)',color='blue')
plt.legend(loc='lower right')

# %% [markdown]
# ### Things to note

# %%
#make plot look nicer using np.linspace

x=np.array([0,1,2,3,4,5,6])
x=np.linspace(0,6,100) #start from 0, end on 6, generate 100 items
x2=x**2 
sin_x=np.sin(x)

plt.plot(x,x2,label='x^2',color='red',linestyle='dashed')
plt.legend(loc=(.25,.5), frameon=False) #specify legend location using coordinates

plt.twinx()

plt.plot(x,sin_x,label='sin(x)',color='blue')
plt.legend(loc=(.25,.45), frameon=False)

#frameon= False -> legend will not be surrounded by a coloured border

# %% [markdown]
# # 3 Saving to disc

# %%
x=np.array([0,1,2,3,4,5,6])
x=np.linspace(0,6,100) #start from 0, end on 6, generate 100 items
x2=x**2 
sin_x=np.sin(x)

plt.plot(x,x2,label='x^2',color='red',linestyle='dashed')
plt.legend(loc=(.25,.5), frameon=False) #specify legend location using coordinates

plt.twinx()

plt.plot(x,sin_x,label='sin(x)',color='blue')
plt.legend(loc=(.25,.45), frameon=False)

#using plot as image, save to disk
#savefig() function
#specify format with extension, filename.pdf (can export into pdf, jpeg, png etc)
#specify resolution by dots per inch (dpi), can increase dpi for higher reso
#will be saved in the same folder as this notebook aka PLOTTING
plt.savefig('C:\\Users\Qing\Downloads\simple-plot.pdf',dpi=300)
#C:\ doesnt work, need C:\\

# %% [markdown]
# # 4 A real example: Global Warming

# %% [markdown]
# ## 4.1 Plotting data from files

# %%
data=np.loadtxt('Complete_TAVG_daily.txt',skiprows=24) #skiprows skip first 24 rows

date=data[:,0] #extract numbers of first column of every row
anomaly=data[:,-1] #extract numbers of last column of every row
#works as numpy arrays

plt.plot(date,anomaly,alpha=.5) #alpha to adjust opacity of plot
plt.ylim([-8,8]) #range of y axis, if x axis then xlim

plt.hlines(0,date[0],date[-1],linestyle='dashed',color='grey')
#hlines() add horizontal line at zero
#plt.hlines(y value, starting x value, ending x value)

# %% [markdown]
# ## 4.2 Styles

# %%
plt.style.use('fivethirtyeight')
#using matplotlib standard style templates
#this line must be at the top

date=data[:,0] 
anomaly=data[:,-1] 

plt.plot(date,anomaly,alpha=.5) 
plt.ylim([-8,8]) 

plt.hlines(0,date[0],date[-1],linestyle='dashed',color='grey')

plt.xlabel('Date')
plt.ylabel('Temperature Anomaly')
plt.title('Temperature anomaly/n(Relative to average from Jan 1951 - Dec 1980)')
# Out:
# Text(0.5, 1.0, 'Temperature anomaly/n(Relative to average from Jan 1951 - Dec 1980)')

# %% [markdown]
# ### xkcd!

# %%
plt.xkcd()
#ignore warning messages, this appears because style not properly installed

date=data[:,0] 
anomaly=data[:,-1] 

plt.plot(date,anomaly,alpha=.5) 
plt.ylim([-8,8]) 

plt.hlines(0,date[0],date[-1],linestyle='dashed',color='grey')

plt.xlabel('Date')
plt.ylabel('Temperature Anomaly')
plt.title('Temperature anomaly/n(Relative to average from Jan 1951 - Dec 1980)')
# Out:
# Text(0.5, 1.0, 'Temperature anomaly/n(Relative to average from Jan 1951 - Dec 1980)')
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %% [markdown]
# ### Resetting styles

# %%
#reset style need to set to default style
plt.style.use('default')

date=data[:,0] 
anomaly=data[:,-1] 

plt.plot(date,anomaly,alpha=.5) 
plt.ylim([-8,8]) 

plt.hlines(0,date[0],date[-1],linestyle='dashed',color='grey')

plt.xlabel('Date')
plt.ylabel('Temperature Anomaly')
plt.title('Temperature anomaly/n(Relative to average from Jan 1951 - Dec 1980)')
# Out:
# Text(0.5, 1.0, 'Temperature anomaly/n(Relative to average from Jan 1951 - Dec 1980)')
